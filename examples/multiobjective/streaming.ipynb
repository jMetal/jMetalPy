# %%
import time
import random
import numpy as np
import pandas as pd
import holoviews as hv

from holoviews.streams import Pipe

import streamz
import streamz.dataframe

hv.extension('matplotlib')
# Out:
# <link rel="stylesheet" href="https://code.jquery.com/ui/1.10.4/themes/smoothness/jquery-ui.css">
# <style>div.hololayout {
#   display: flex;
#   align-items: center;
#   margin: 0;
# }
#
# div.holoframe {
#   width: 75%;
# }
#
# div.holowell {
#   display: flex;
#   align-items: center;
# }
#
# form.holoform {
#   background-color: #fafafa;
#   border-radius: 5px;
#   overflow: hidden;
#   padding-left: 0.8em;
#   padding-right: 0.8em;
#   padding-top: 0.4em;
#   padding-bottom: 0.4em;
#   box-shadow: inset 0 1px 1px rgba(0, 0, 0, 0.05);
#   margin-bottom: 20px;
#   border: 1px solid #e3e3e3;
# }
#
# div.holowidgets {
#   padding-right: 0;
#   width: 25%;
# }
#
# div.holoslider {
#   min-height: 0 !important;
#   height: 0.8em;
#   width: 100%;
# }
#
# div.holoformgroup {
#   padding-top: 0.5em;
#   margin-bottom: 0.5em;
# }
#
# div.hologroup {
#   padding-left: 0;
#   padding-right: 0.8em;
#   width: 100%;
# }
#
# .holoselect {
#   width: 92%;
#   margin-left: 0;
# ...

# %%
class Streaming:
    
    def __init__(self, dimension: int):
        point_source = streamz.Stream()
        self.pipe = Pipe(data=[])
        
        # Connect streamz to the Pipe
        point_source.sliding_window(100).map(pd.concat).sink(self.pipe.send)

        if dimension == 2:
            self.dmap = hv.DynamicMap(hv.Scatter, streams=[self.pipe])
        elif dimension == 3:
            self.dmap = hv.DynamicMap(hv.Scatter3D, streams=[self.pipe])            
        
    def update(self, points):
        self.pipe.send(points)
    
    def show(self):
        return self.dmap

# %%
vis = Streaming(2)
vis.show()
# Out:
# :DynamicMap   []
#    :Scatter   [x]   (y)

# %%
for i in range(100):
    vis.update([(i, np.random.random()) for i in range(20)])
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-154-2872e8510b28> in <module>()
#       1 for i in range(100):
# ----> 2     time.sleep(0.1)
#       3     vis.update([(i, np.random.random()) for i in range(20)])
#
# KeyboardInterrupt:

# %%
vis = Streaming(3)
vis.show()
# Out:
# No plotting class for Scatter3D found
# :DynamicMap   []
#    :Scatter3D   [x,y,z]

# %%
for i in range(100):
    vis.update([(i, np.random.random(), np.random.random()) for i in range(20)])
