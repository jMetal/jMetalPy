# %% [raw]
# .. _nb_nsgaiii:

# %% [markdown]
# ## NSGA-III

# %% [markdown]
# ### API

# %% [raw]
# .. autoclass:: jmetal.algorithm.multiobjective.nsgaiii.NSGAIII
#    :members:
#    :undoc-members:
#    :show-inheritance:
